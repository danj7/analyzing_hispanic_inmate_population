# %% [markdown]
# # Polk County Current Inmates

# %% [markdown]
# Loading libraries...

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %% [markdown]
# ## Getting the inmate data

# %% [markdown]
# This is the web address where we get the inmate data.

# %%
url_polk_domain = 'https://apps.polkcountyiowa.gov' #used to access inmate details
url_polk_curr_inmates = url_polk_domain +'/PolkCountyInmates/CurrentInmates'

# %% [markdown]
# The tables are not shown in the source html, so a Selenium WebDriver is used to emulate the browser and automate the extraction of the data.

# %%
#I am emulating a Firefox browser.
#The driver is set to work in headless mode so it doesn't bring up a browser window.
ffoptions = webdriver.firefox.options.Options()
ffoptions.headless = True
#The driver is defined and wait time is set (though I am not 100% sure how it works).
driver = webdriver.Firefox(options=ffoptions)
driver.implicitly_wait(30)

# %% [markdown]
# Getting the website with the list of current inmates.

# %%
driver.get(url_polk_curr_inmates)
time.sleep(1)
#using Beautiful Soup to parse the html and make it easier to extract data.
soup_polk = BeautifulSoup(driver.page_source)
#In the driver page source the table with the data is present.
rows = soup_polk.find_all('tr')
rows.pop(0) #removing table header with titles
total_inmates = len(rows)
print('Number of inmates in sample =', total_inmates)
# Out:
# Number of inmates in sample = 881

# %% [markdown]
# The table extracted above has partial names and a link to each inmate's personal data, so we need to access that link.
# A list of those links is created with the following cell.

# %%
details_page_list = []

for row in rows:
    details_page_list.append(row.find('a')['href'])
#
print('# of detail pages =',len(details_page_list))
# Out:
# # of detail pages = 881

# %% [markdown]
# Each details page is accessed and the name and race is extracted. This step takes quite a bit of time.

# %%
inmate_names = []
inmate_races = []

for i, detail_page in enumerate(details_page_list):
    driver.get(url_polk_domain+detail_page)
    #time.sleep(.1) #just in case, maybe not
    details_page_text = BeautifulSoup(driver.page_source)
    labels = details_page_text.find_all('label')
    name = labels[1].next_sibling.strip()
    race = labels[8].next_sibling.strip()
    inmate_names.append(name)
    inmate_races.append(race)
    print('item #{}:'.format(i),'name =', name, '; race =', race)
#
assert len(inmate_names) == total_inmates, "Some inmates' data is missing!"
assert len(inmate_races) == total_inmates, "Some inmates' data is missing!"
# Out:
# item #0: name = SHANE D MILLER ; race = White
# item #1: name = MARK ANTHONY WILSON ; race = Black
# item #2: name = SHAVAUGHN ELIZABETH KAY GARDNER ; race = Black
# item #3: name = JULIE ANN LUNDY ; race = Unknown
# item #4: name = TYLOR MICHAEL DAVIS ; race = White
# item #5: name = DAVID LEE MOORE ; race = Black
# item #6: name = KELLEY EUGENE ALLBEE ; race = White
# item #7: name = AUSTIN DOMINIC BARKER ; race = White
# item #8: name = KALEB VAN LUONG ; race = Asian
# item #9: name = DONALD LEROY STEELE ; race = Black
# item #10: name = CLARENCE RAPIER NANCE ; race = Black
# item #11: name = JIMMY RAY SMITH ; race = Black
# item #12: name = TRACY LEIGH JONES ; race = White
# item #13: name = ALLISON DANIELLE DOYLE ; race = White
# item #14: name = CHARLES LAKEYRIC FUNCHES ; race = Black
# item #15: name = BRANDON JOSEPH GIBSON ; race = White
# item #16: name = ASAAD RESHAN JABIR ; race = White
# item #17: name = LESLEY DALE DUCKWORTH ; race = White
# item #18: name = ALEC WADE LARSON ; race = White
# item #19: name = SYDNEY MARIE PRICE ; race = White
# item #20: name = BRANDY LEU BIEGGER ; race = White
# item #21: name = THOMAS JAMES WHITE ; race = White
# item #22: name = MARIJKE JOY HODGSON ; race = White
# item #23: name = JONATHON CRAIG BUSHBY ; race = White
# item #24: name = SHELBY THOMPSON SAMMONS ; race = White
# item #25: name = JONATHAN D SMITH ; race = Black
# item #26: name = FELIX  GOMEZ ; race = White
# item #27: name = KOURI LEE OLSON ; race = White
# item #28: name = EUGENE MICHAEL ANTHONY ; race = White
# item #29: name = ROGER MICHAEL HAND ; race = White
# item #30: name = JONATHAN J MERRYFIELD ; race = White
# item #31: name = JAMES ROBERT STEWART ; race = White
# item #32: name = WHITNEY MARIE CAMERON ; race = Black
# item #33: name = TROY HARLEY JORGENSEN ; race = White
# item #34: name = MARONDE  SWEDI ; race = Black
# item #35: name = NICOLE ELIZABETH LINKER ; race = White
# item #36: name = CHARLES ALLEN TURNER ; race = Black
# item #37: name = ANTONIO LUCHION HARGROW ; race = Black
# item #38: name = GRANT JACKSON KITCHEN ; race = White
# item #39: name = KIM OCTAVIA FRANCIS ; race = Black
# item #40: name = MIGUEL ANGEL PEREZ ; race = White
# item #41: name = JOSE DEJESUS GALVAN SOTO ; race = White
# item #42: name = ERICA LYNN SHALES ; race = White
# item #43: name = JACK ANTHONY RICHARDS ; race = White
# item #44: name = LAWRENCE RICHARD MACKEN ; race = White
# item #45: name = CLARENCE RAY DELMOTT ; race = White
# item #46: name = DOUGLAS KINUTHIA NGUGI ; race = Black
# item #47: name = EMMANUEL NATHANIEL MAGANG ; race = Black
# item #48: name = MARIE ASHLEY SWIER ; race = White
# item #49: name = TOMAZ XAVIER BRUCE ; race = Black
# item #50: name = TROY STEPHEN WESTPHAL ; race = White
# item #51: name = GEORGE  WOODS ; race = Black
# item #52: name = DAVID EUGENE WYCKOFF ; race = White
# item #53: name = JARED WILLIAM LEE ALDERMAN ; race = White
# item #54: name = MARRKELL RACHAE MCGRIFF ; race = Black
# item #55: name = MARYETTA ANNA FORTUNE ; race = White
# item #56: name = TYLAR AARON LEE COFFMAN ; race = Pacific Islander
# item #57: name = CHRISTOPHER LEE SHEETS ; race = White
# item #58: name = JESUITA ANN WARREN ; race = Black
# item #59: name = MARCUS DECARLO BROWN ; race = Black
# item #60: name = DEJANNA PARISH BORBA ; race = White
# item #61: name = DUSTIN EDWARD FICKES ; race = White
# item #62: name = BOOKER TALIFERRO JARRETT ; race = Black
# item #63: name = BRYAN TYLER NORRIS ; race = White
# item #64: name = CHELSEA AMBER DROWN ; race = White
# item #65: name = STEVEN CRAIG GRAY ; race = White
# item #66: name = CLAYTON JAMES REEVES ; race = White
# item #67: name = ROBERT LLOYD HARRISON ; race = White
# item #68: name = RICHARD ARTHUR MAJERUS ; race = White
# item #69: name = FAWSIA ADEN GEIRE ; race = Black
# item #70: name = DAMON JAMES LEVERICH ; race = White
# item #71: name = CEDRIC BENARD BAILEY ; race = Black
# item #72: name = JEFFREY MARSHALL VOYCE ; race = White
# item #73: name = JOHN WESLEY TURNER ; race = White
# item #74: name = KYLE DAVID SHORT ; race = White
# item #75: name = DOROTHY MARIE KEMBOI ; race = Black
# item #76: name = RAHIM MOHAMMAD KHOSHDEL ; race = Asian
# item #77: name = DUSTIN STEVEN CONRAD ; race = White
# item #78: name = ALSTON RAY CAMPBELL ; race = Black
# item #79: name = CHAD LEED CHRISTENSEN ; race = White
# item #80: name = DALE JEROME AMEIGH ; race = White
# item #81: name = MICHAEL MARTIN SAWYER ; race = White
# item #82: name = SHAWN DANIEL LARSEN ; race = White
# item #83: name = DANNY LEE JACKSON ; race = White
# item #84: name = ROBERT DEAN HENDERSON ; race = White
# item #85: name = KEVIN JOE KULISKY ; race = White
# item #86: name = MICHAEL JOSEPH GALLO ; race = White
# item #87: name = DONALD ALDO MEDICI ; race = White
# item #88: name = CODY DANE HORNE ; race = White
# item #89: name = JESSICA ROSE MCDONALD ; race = White
# item #90: name = FELICIA BOUALAY PERRY ; race = Asian
# item #91: name = JORGE ALBERTO FRANCO ; race = White
# item #92: name = DOUGLAS KENT MCLEY ; race = White
# item #93: name = ERIC KEITH BULLARD ; race = White
# item #94: name = JONATHAN WILLIAM FLETCHER ; race = Black
# item #95: name = ASHLEY DAWN HOYT ; race = White
# item #96: name = KANDICE LYNN PEAK ; race = White
# item #97: name = ROBERT AUSTIN KILLINS ; race = White
# item #98: name = BRANDON MICHAEL ROBERTS ; race = White
# item #99: name = JOSEPH MICHAEL BARRESE ; race = White
# item #100: name = DAVID JOHN MERLEY ; race = White
# item #101: name = ROBERT SCOTT RAHMLOW ; race = White
# item #102: name = ROSCOE CORTEZ GREEN ; race = Black
# item #103: name = VIRGIL JOSEPH JOHNSON ; race = White
# item #104: name = BRIEN LEROY WATSON ; race = White
# item #105: name = PAH MAE SOD ; race = Asian
# item #106: name = JENNIFER LEE SIMONSEN ; race = White
# item #107: name = TORI LYNN ROACH ; race = White
# item #108: name = CHAD ALLEN YAW ; race = White
# item #109: name = JILL SHOREY CUTLER ; race = White
# item #110: name = CHRISTOPHER LYNN LONG ; race = White
# item #111: name = DAMIAN LUIS DIAZ ; race = White
# item #112: name = DARREN ULYSSES BUTTS ; race = Black
# item #113: name = CONNER THOMAS BEURSKENS ; race = White
# item #114: name = PAYE  BLAWOU ; race = Black
# item #115: name = JOCELYN  RAMIREZ ; race = White
# item #116: name = BRENT LEON SKELTON ; race = White
# item #117: name = DANIEL JOSEPH BAILEY ; race = White
# item #118: name = JACOB ALAN HAMILTON ; race = White
# item #119: name = JOSHUA ERICK BUFFUM ; race = White
# item #120: name = JOEL RENDEROS GOMEZ ; race = White
# item #121: name = TRACEY LAMARR LUV MURE ; race = Black
# item #122: name = JORDAN SETH JOHNSON ; race = White
# item #123: name = KENDRICK REECE EPPING ; race = White
# item #124: name = DANYAL DENG ANGUEY ; race = Black
# item #125: name = EMILY ANNE ROMAINE ; race = White
# item #126: name = CODY ALLEN CURTIS ; race = White
# item #127: name = RYAN SCOTT BROOKS ; race = White
# item #128: name = PEYTON LEE MORRISON ; race = White
# item #129: name = JASON EUGENE HOLBROOK ; race = White
# item #130: name = CHRISTOPHER LEE FRANKLIN ; race = Pacific Islander
# item #131: name = WESLEY EUGENE MIHALOVICH ; race = White
# item #132: name = ELIZABETH JOAN WILLIAMS ; race = White
# item #133: name = ANDREW AMOS GRIFFIN ; race = White
# item #134: name = DANIEL SHANE HOLMES ; race = White
# item #135: name = LINSEY ANN BRADFORD ; race = White
# item #136: name = SYLVESTER SAYBAH BARJOLO ; race = Black
# item #137: name = DEMETRIUS LAVELL BIRTH ; race = Black
# item #138: name = JOSHUA DAVID MADDIX ; race = White
# item #139: name = SAMUEL AARON JOHNSON ; race = White
# item #140: name = JEFFREY ALLEN WELCH ; race = Black
# item #141: name = MICHELLE LYNN MCGUIRE ; race = White
# item #142: name = SHARMARKE OMAR MOHAMED ; race = Black
# item #143: name = MICHAEL PATRICK ARTWEIN ; race = White
# item #144: name = JIMMY JERIMIAH COAH ; race = Black
# item #145: name = HECTOR  CAMACHO ; race = White
# item #146: name = STEPHEN MARCO MEJA ; race = Black
# item #147: name = RYAN CHANCE KENDALL ; race = White
# item #148: name = AUBREY CHASE WATERS ; race = White
# item #149: name = TERRY D JACKSON ; race = Black
# item #150: name = ROBERT LEE KIRK ; race = White
# item #151: name = PHILIP ALONZO JOHNSON ; race = Black
# item #152: name = RENAE NICOLE CLARK ; race = White
# item #153: name = BRIAN WAYNE AGEE ; race = White
# item #154: name = ALEXANDER MICHAEL BERRY ; race = White
# item #155: name = CHRISTOFER JOHNATHAN KELLING ; race = White
# item #156: name = TROY ANTHONY BURNEY ; race = White
# item #157: name = MICHAEL JAY WHALEN ; race = White
# item #158: name = DONTE JOMARTENEU JAMES ; race = Black
# item #159: name = GASTON  KEAHNA ; race = Pacific Islander
# item #160: name = TRAYANTWON DESHAE THOMAS ; race = Black
# item #161: name = KATIE ANNE HERGERT ; race = White
# item #162: name = JOSHUA DEE HILL ; race = White
# item #163: name = ALEC RYAN STEFFES ; race = White
# item #164: name = JULIE ARLENE CHRISTY ; race = White
# item #165: name = KEVIN JACOB CARLTON ; race = White
# item #166: name = BRIAN ROSCOE WELTZIN ; race = White
# item #167: name = BILL LEE SIMET ; race = White
# item #168: name = DENTERRELL LOUIS EWING BUTTS ; race = Black
# item #169: name = DEANTA RAMON TAYLOR ; race = Black
# item #170: name = WILLIAM ROSS CLARK ; race = White
# item #171: name = GILBERTO JESUS MOTA ; race = White
# item #172: name = JEREMY EDWARD RIDNOUR ; race = White
# item #173: name = DAVID JAMES DERMODY ; race = White
# item #174: name = TULSI RAM MAINALI ; race = Asian
# item #175: name = CHARLIE COLE STROUD ; race = White
# item #176: name = RICHARD LEE RAY ; race = White
# item #177: name = EARL RYAN ANTHONY WAGNER ; race = White
# item #178: name = RYAN JAMES PLEW ; race = White
# item #179: name = CHRISTIAN CHASE COMBS ; race = White
# item #180: name = JASON ALLEN HEDGECOTH ; race = White
# item #181: name = NICHOLAS ALLEN CANNON ; race = White
# item #182: name = CORNELIUS NARVELL HENNINGS ; race = Black
# item #183: name = GEORGE ALLEN LADEHOFF ; race = White
# item #184: name = ASHLEY ANNE MIKKELSEN ; race = White
# item #185: name = MICHELLE LYNN MERCK ; race = White
# item #186: name = HENRY ARTURO HERNANDEZ LEYVA ; race = White
# item #187: name = RAMI AUGUSTINO TOMBE ; race = Black
# item #188: name = RAYMOND COLTON JONES ; race = White
# item #189: name = SAMANTHA LYNN JACKMAN ; race = White
# item #190: name = TYLER LUKE CRITCHLOW ; race = Black
# item #191: name = JUAN EDUARDO TORRES CAMACHO ; race = White
# item #192: name = MICHAEL DANIEL BROOKS ; race = Black
# item #193: name = JOSHUA NATHANIEL BAKER ; race = Black
# item #194: name = LEAH LEONA PERISH ; race = White
# item #195: name = GERARDO  SANTIAGO BAUTISTA ; race = White
# item #196: name = JOSEPH ADAM GONZALEZ ; race = White
# item #197: name = CAROL  GRAVES ; race = White
# item #198: name = RYAN SPENCER FISTER ; race = Black
# item #199: name = MCKYLE MALIK WILSON ; race = Black
# item #200: name = MARKEL KAREEM SANDERS ; race = Black
# item #201: name = JUANITO  HERNANDEZ ; race = White
# item #202: name = MEGAN LEONA WOOD ; race = White
# item #203: name = HENRY JAMES HILL ; race = Black
# item #204: name = DOMONICK ALLEN SMITH ; race = White
# item #205: name = DAWN PATRICIA JARNAT ; race = White
# item #206: name = RAIFE HUNTER KUBAL ; race = White
# item #207: name = GABRIEL MICHAEL MEYERS ; race = White
# item #208: name = ERIC TYRONE DAUGHERTY ; race = Black
# item #209: name = HOLLY LYNN WINLAND ; race = White
# item #210: name = MARCUS JAY BROADUS ; race = Black
# item #211: name = TORRANCE WILLIAM ROBERSON ; race = White
# item #212: name = CHASE CLAY GUSTAFSON ; race = White
# item #213: name = ERIC ALAN JOHNSON ; race = White
# item #214: name = RUEBEN LEE HICKMAN ; race = Black
# item #215: name = WILLIE DAVID BEASLEY ; race = Black
# item #216: name = NATHANIEL PETER SOUMAS ; race = White
# item #217: name = ELIZABETH LAREE JOHNSON ; race = White
# item #218: name = ANDREW AARON VRIEZELAAR ; race = White
# item #219: name = SHANNON MARIE KING ; race = White
# item #220: name = PRESTON KULEH HOOKS ; race = Black
# item #221: name = BRITTANY LEE FRANKLIN ; race = White
# item #222: name = MIKAYLA CHRISTIAN LEPLEY ; race = White
# item #223: name = KOLE ANAKIN CRITCHLOW ; race = White
# item #224: name = DUSTIN EUGENE MOAD ; race = White
# item #225: name = DAVID EUGENE NORDYKE ; race = White
# item #226: name = GEORGE CALVIN MCCUTCHEN ; race = Black
# item #227: name = BRIAN ANDREW HUCKFELDT ; race = White
# item #228: name = KENDRICK WINDSOR SPEIGHT ; race = Black
# item #229: name = BERNABE  MARTINEZ VAZQUEZ ; race = White
# item #230: name = TYJAUN LEVELL TUCKER ; race = Black
# item #231: name = GEORGE WILLIAM PAUL GASKEY ; race = White
# item #232: name = AICHATOU  MOUSSA ; race = Black
# item #233: name = JEREMY GLENN VIRDEN ; race = White
# item #234: name = MASON JEREMY PARNAU ; race = White
# item #235: name = DAVID PATRICK FERRARI ; race = White
# item #236: name = RICHARD ELLIOTT NORSEN ; race = White
# item #237: name = JOSHUA TERRELL CROSS ; race = Black
# item #238: name = PRAJWAL  BHANDARI ; race = Asian
# item #239: name = SITA  KARKI ; race = Asian
# item #240: name = JARMIER LANEL SHEPARD ; race = Black
# item #241: name = RICHARD ANDREW JACKSON ; race = White
# item #242: name = RYAN DAVID STOUT ; race = White
# item #243: name = JAMES RONALD COWLES ; race = White
# item #244: name = CASSI MAE BIRD ; race = White
# item #245: name = ANDRES JERIAH GLEASON ; race = White
# item #246: name = TERRELL RUSEAN FARLEY ; race = Black
# item #247: name = MIGUEL  MORALES ; race = White
# item #248: name = LORAN SHAE WOLETT ; race = White
# item #249: name = JAMARR MIKELE JONES ; race = Black
# item #250: name = CHRISTOPHER LEO THEN ; race = White
# item #251: name = CODY TYLER DYER ; race = White
# item #252: name = JEFFREY ALAN WEBB ; race = White
# item #253: name = BROOK TAYLOR HARMS ; race = White
# item #254: name = FREDDRICK CLEAVEN LITTLE ; race = Black
# item #255: name = OBISPO  ESTRADA OROZCO ; race = White
# item #256: name = ZACHARY MICHAEL JANSSEN ; race = White
# item #257: name = DOT ALERKOAL GOK ; race = Black
# item #258: name = DEBORAH LYNN PEYER ; race = White
# item #259: name = EBENEZER SUNNY FODAY ; race = Black
# item #260: name = ANTHONY MICHAEL GYLES ; race = White
# item #261: name = JOE ELVIN FARNUM ; race = White
# item #262: name = BRIAN WAYNE ZIMMERMAN ; race = White
# item #263: name = LASHAUNA RUSHELLE BAILEY ; race = Black
# item #264: name = ALONZO BURL TRAVIS ; race = Black
# item #265: name = KIMBERLY MARIE BLANCHARD ; race = White
# item #266: name = JUAN  CRUZ GARCIA ; race = White
# item #267: name = ZACHARY RYAN NULPH ; race = White
# item #268: name = ANDREW JOHN DANIELS ; race = White
# item #269: name = STANLEY PAUL WOFFORD ; race = Black
# item #270: name = MICHAEL NICHOLAS HENLE ; race = Black
# item #271: name = MELISSA MAE WOOSTER ; race = White
# item #272: name = CAMERON WALTER KENNEDY ; race = Black
# item #273: name = LAMARR CORTEZ HUNT ; race = Black
# item #274: name = FELLA JAMES FELLA ; race = Black
# item #275: name = TIMOTHY JOE RIOS ; race = White
# item #276: name = ABDALLA ELEHAMIR MOUSA ; race = Black
# item #277: name = JESSICA KAY FISHER ; race = White
# item #278: name = CHASE RANSOM FOSTER ; race = White
# item #279: name = JOHNATHAN JAY HOSKINS ; race = White
# item #280: name = KRISTA JANE MIFLIN ; race = White
# item #281: name = CHASE AUSTEN MAILLOUX ; race = White
# item #282: name = CHRISTOPHER EUGENE GILBERT ; race = White
# item #283: name = JEREMY STUART CHRISTIANI ; race = White
# item #284: name = JACOB LEE FARNSWORTH ; race = White
# item #285: name = TREVER RAY VINZANT ; race = White
# item #286: name = GETHSACKDA WHITNEY NANTHANORATH ; race = Asian
# item #287: name = LINDA LARRIEN ASHMORE ; race = White
# item #288: name = DARYL BIXBY MERRILL ; race = White
# item #289: name = DENNIS LEE MONSMA ; race = White
# item #290: name = TARRANCE OLIVER SHACKFORD YOUNGBEAR ; race = Black
# item #291: name = JUSTIN MICHAEL ARCHER ; race = White
# item #292: name = CHANELL DOMINQUE AISSA SISSOKO ; race = Black
# item #293: name = DARYL EUGENE CAMPBELL ; race = Black
# item #294: name = ANA PATRICIA ORDAZ ; race = White
# item #295: name = JEFFREY DUWANE CAUDLE ; race = White
# item #296: name = ALBERT  HARDEN ; race = Black
# item #297: name = KATLYN SHAI LE MIKOHL LOVELY ; race = White
# item #298: name = ASHLEY LEE IMMERFALL ; race = White
# item #299: name = CHRISTOPHER GLEN HANLIN ; race = White
# item #300: name = DALE STEVEN HARVEY ; race = White
# item #301: name = TRAVIS GRANT JOHNSON ; race = White
# item #302: name = RONALD ROY AYERS ; race = Black
# item #303: name = BITA  AMISI ; race = Black
# item #304: name = JAMES MICHAEL MOORE ; race = Black
# item #305: name = DAVID LEE HELTON ; race = White
# item #306: name = TEK BAHADUR BISWA ; race = White
# item #307: name = CURTIS MARTELL GINES ; race = Black
# item #308: name = DONTRE MAURICE ENGLISH LEWIS ; race = Black
# item #309: name = ASHLEY RENEE BROWN ; race = Black
# item #310: name = VANCE EDWARD WILLIAMS ; race = Black
# item #311: name = JAMES THOMAS VASEY ; race = Black
# item #312: name = ROBERT J VANGUNDY ; race = White
# item #313: name = ANISSA RENEA ANDERSON ; race = White
# item #314: name = JEFFREY TRAE PHILLIPS ; race = White
# item #315: name = ANDREW RICHARD KOLOMER ; race = White
# item #316: name = JOE NAPEH YANKOON ; race = Black
# item #317: name = DEBORAH LYNN WEIR ; race = White
# item #318: name = DAVID KEITH SAWHILL ; race = White
# item #319: name = MARIO LUCIANO ANTHONY ; race = Pacific Islander
# item #320: name = CHRISTOPHER WILLIAM COATES ; race = White
# item #321: name = LAURIE ANN WARNER ; race = White
# item #322: name = DYLAN CHRISTIAN KAVAN ; race = Asian
# item #323: name = MICHAEL SCOTT NEUBAUER ; race = White
# item #324: name = JENNIFER LEA REYNOLDS ; race = White
# item #325: name = ANGELA MARIE SEARS ; race = White
# item #326: name = ANDREW LANTA BOYD ; race = Black
# item #327: name = SONA ANDU MENA ; race = Black
# item #328: name = ANGELICA NOEL BLEECHER ; race = White
# item #329: name = PHARROEL LEEMAN HALL ; race = Black
# item #330: name = ADAM WAYNE JENSEN ; race = White
# item #331: name = DANNY EUGENE RUMBAUGH ; race = White
# item #332: name = JAKE DION ASHLEY ; race = White
# item #333: name = SHARAY NICOLE BENGE ; race = White
# item #334: name = CARLIN WAYNE INGLEDUE ; race = White
# item #335: name = CAPRIECE ANNE CHARTPENTIER ; race = Black
# item #336: name = JOHN EDWARD HAYNER ; race = White
# item #337: name = TERRY DEAN HANKINS ; race = White
# item #338: name = RONDALE DEVON BROWN ; race = Black
# item #339: name = ROBERT MILTON JONES ; race = Black
# item #340: name = JOSHUA JOHN UNGS ; race = White
# item #341: name = JOHNNY PHILLIP DELFRANO ; race = White
# item #342: name = RHONDA LOU DUDLEY ; race = White
# item #343: name = WOUR NATHANIEL MAGANG ; race = Black
# item #344: name = ADAM CHARLES WOLFE ; race = White
# item #345: name = ANTHONY DELANO BRUCE ; race = Black
# item #346: name = MATTHEW ALAN RUNNER ; race = White
# item #347: name = JAMES MICHAEL SADLER ; race = Black
# item #348: name = ADDIE MARIE WILLIAMS ; race = Black
# item #349: name = TABITHA LYNNETTE HARDIN ; race = White
# item #350: name = ROBERT LEE SMITH ; race = White
# item #351: name = JEFFERY WAYNE BOWEN ; race = White
# item #352: name = KEJUAN TYRELL GIBSON ; race = Black
# item #353: name = SHANE ALEXANDER NEWTON ; race = White
# item #354: name = TROY ROSHAWN JENKINS ; race = Black
# item #355: name = QUENTIN LUEL GAVIN ; race = Black
# item #356: name = WILLIAM FRANKLIN HERMAN ; race = Black
# item #357: name = TAMMY LYNN TATE ; race = White
# item #358: name = ISAAC POOKELA NAVARRO TORRES ; race = Asian
# item #359: name = KENAD KENO ZUKIC ; race = White
# item #360: name = ARCHALETTA LATRICE YOUNG ; race = Black
# item #361: name = FRANCESCA  EVANS ; race = White
# item #362: name = NICKIE LYNN SIRACUSANO ; race = White
# item #363: name = GABRIELA GABRIELA JEMERIGBE ; race = White
# item #364: name = HAITHAM ARA ABDEL MAJID ; race = White
# item #365: name = BRADLEY THOMAS BUHRER ; race = White
# item #366: name = MAYMIE ALICE JENKINS ; race = White
# item #367: name = NATHAN ANTHONY AMADEO ; race = White
# item #368: name = ADAM ROBERT WALSKE ; race = White
# item #369: name = GAGE TAYLOR OLSON ; race = White
# item #370: name = MELISSA ANNE SAPP ; race = White
# item #371: name = CRISMA RACHELL FRANKS ; race = Black
# item #372: name = ANDREW CAMERON EDWARDS ; race = White
# item #373: name = CHRISTOPHER MATTHEW KHAN HOANGVAN ; race = Asian
# item #374: name = TIMOTHY JAMES DUNPHY ; race = White
# item #375: name = ANTHONY JOHN FORMARO ; race = White
# item #376: name = WILLIAM ANTHONY PAYNE ; race = Black
# item #377: name = LATICE MARIE WILLIAMS ; race = Black
# item #378: name = RICKY LEE COCHRAN ; race = White
# item #379: name = RONALD DUANE EISENAUER ; race = White
# item #380: name = CHRISTY LOU JOHNSON ; race = White
# item #381: name = CHASE JOSEPH MEIER ; race = White
# item #382: name = SAMANTHA ROSE GRAHAM ; race = White
# item #383: name = KAYSHAWNA DENISE KINNEY ; race = Black
# item #384: name = MARCUS LEWIS JONES ; race = White
# item #385: name = DAVID LEE STRANC ; race = White
# item #386: name = MARC ALLEN EIDE ; race = White
# item #387: name = TONYA LAVERNE EIDE ; race = White
# item #388: name = JEFFERY ALLEN JOHNSTON ; race = White
# item #389: name = MYRON DEMON NICHOLS ; race = Black
# item #390: name = CODY RAY BROWN ; race = White
# item #391: name = DIRK VONDELL JORDAN ; race = Black
# item #392: name = TRISTAN KYLE NELSON ; race = White
# item #393: name = JOSEPH ALLEN CUNNINGHAM ; race = White
# item #394: name = HAILEY ORION WALKER ; race = White
# item #395: name = AVERY EUGENE WHITE ; race = Pacific Islander
# item #396: name = DONTAVIOUS MIGUEL JACKSON ; race = Black
# item #397: name = REBECCA KAY GARNER ; race = White
# item #398: name = MONTRAY DEVON LITTLE ; race = Black
# item #399: name = RONALD RAY ROGERS ; race = White
# item #400: name = HENG  NGAN ; race = Asian
# item #401: name = AYUEL ATEM BONG ; race = Black
# item #402: name = KEITH EUGENE LUCAS ; race = White
# item #403: name = AMY DANIELLE PORTER ; race = White
# item #404: name = PHILLIP SCOTT KELLY ; race = Black
# item #405: name = JOSEPH ANTHONY LUNA ; race = White
# item #406: name = ASHLEY NICOLE THOMPSON ; race = White
# item #407: name = ALMIR  KUCUKOVIC ; race = White
# item #408: name = WILLIAM LESTER LANE ; race = White
# item #409: name = TIMOTHY MATHEW NAIL ; race = White
# item #410: name = DAVID LEE YOM ; race = Asian
# item #411: name = DAVID MICHAEL HUNT ; race = White
# item #412: name = DAVID MARK WHITMORE ; race = White
# item #413: name = SHAWN MARCELL LONG ; race = Black
# item #414: name = SCOTT BRENT MILLER ; race = White
# item #415: name = ANDREW GORDON MEYER ; race = White
# item #416: name = TAPANGA ALEASE CLAIR ; race = White
# item #417: name = ARRON LASHAWN LOGAN ; race = Black
# item #418: name = ASHLEY MARIE JONES ; race = White
# item #419: name = JEROME JEREMY HAYNES ; race = Black
# item #420: name = DAKOTA MICHAEL MCMENAMIN ; race = White
# item #421: name = QUENTIN ALLEN SMITH ; race = White
# item #422: name = ALAN MYRON JONES ; race = White
# item #423: name = AMANDA LYNN BRUGIONI ; race = White
# item #424: name = ORVILLE PAUL HILL ; race = White
# item #425: name = ANGELO JOHN CRESTA ; race = White
# item #426: name = LUCAS JAMES MACK ; race = White
# item #427: name = ALONZO CLAYTON MAYFIELD ; race = Black
# item #428: name = GAJUAN DEJUAN WILLIAMS ; race = Black
# item #429: name = JEREMY FREDRICK BEAR ; race = White
# item #430: name = DRISANA MARIE DAVIS ; race = White
# item #431: name = JOSE MANUEL BALLON ZENDEJAS ; race = White
# item #432: name = AMANDA RUTH BRECKENRIDGE ; race = White
# item #433: name = RICHARD OSMOND MCLACHLAN ; race = Black
# item #434: name = TOREY PAUL REYNOLDS ; race = White
# item #435: name = SHAWN ANN FAGEN ; race = White
# item #436: name = JUSTIN WAYNE SPARKS ; race = White
# item #437: name = DAVID ALAN FOXHOVEN ; race = White
# item #438: name = APOLONIO  GALINDO MENDOZA ; race = White
# item #439: name = CODY MICHAEL ELY ; race = White
# item #440: name = PAUL JOSEPH BORUCH ; race = White
# item #441: name = CECILIA IVONNE MARTINEZ CARATACHEA ; race = White
# item #442: name = KRISTOFER ALLAN ERLBACHER ; race = White
# item #443: name = DAYQUAWNE DASHAWN GATES ; race = Black
# item #444: name = ROBERTO JORGE GARCIA ; race = White
# item #445: name = BRIAN EDWARD SIDERS ; race = White
# item #446: name = GENE AUTRY GATES ; race = Black
# item #447: name = JEREMY GORDON KING ; race = White
# item #448: name = CHRISTOPHER SCOTT CRAWFORD ; race = White
# item #449: name = MARCUS ANTHONY TERRELL ; race = Black
# item #450: name = CLIFTON LABARRON JOHNSON ; race = Black
# item #451: name = TOHAMED JAMOND FOWLER ; race = Black
# item #452: name = JAMES EARL BUSH ; race = Black
# item #453: name = MARQUIS DEVON COLEMAN ; race = White
# item #454: name = DESIREE PEARL-MARYE SWEETMAN ; race = White
# item #455: name = MARIANNE MICHELE WISEMAN ; race = White
# item #456: name = DEVONTE DASAUN-RAY TAYLOR ; race = Black
# item #457: name = ERIC PAUL MCDOWELL ; race = White
# item #458: name = AUSTIN MICHAEL PORTWOOD ; race = White
# item #459: name = NICHOLAS DEAN OVERTON ; race = White
# item #460: name = PHILLIP GAI POK ; race = Black
# item #461: name = SEAN  NOEL ; race = Black
# item #462: name = JAMES ALLEN ROBUCK ; race = White
# item #463: name = BRIAN KING STOVER ; race = White
# item #464: name = JEFFREY PAUL ERICKSON ; race = White
# item #465: name = GREGORY ALLEN WRIGHT ; race = White
# item #466: name = STANLEY EUGENE HOLT ; race = White
# item #467: name = DANIEL LYNN WAUTERS ; race = White
# item #468: name = ZACHARY SCOTT BRADISH ; race = White
# item #469: name = LUKE STEPHEN PETER PETTEY ; race = White
# item #470: name = WILLIAM CHARLES GOOSSENS ; race = White
# item #471: name = ANDREW KENYON HIGHT ; race = White
# item #472: name = JAMES ELMER STRUTH ; race = White
# item #473: name = AISIAH CHRISTOPHER TALTON ; race = Black
# item #474: name = LUIS DAMIAN HERNANDEZ ; race = White
# item #475: name = RUSSELL SCOTT PETTYJOHN ; race = White
# item #476: name = JOSEPH MICHAEL STEWART ; race = White
# item #477: name = TYRONE JEROME HALL ; race = Black
# item #478: name = MICHAEL LEE AGAN ; race = White
# item #479: name = MADISYN SUE HANSEN ; race = White
# item #480: name = KEVIN TYRELLE FLEMING ; race = Black
# item #481: name = CHRISTOPHER ALLEN LONG ; race = White
# item #482: name = BROOKS AARON NORLIN ; race = White
# item #483: name = DONELL LAMARLYNN MUSTIN ; race = Black
# item #484: name = T`END CHRISTOPHER MOTES ; race = Black
# item #485: name = TWYLA JEWEL SCHIEBEL ; race = White
# item #486: name = LEO TRACEY COWLES ; race = Pacific Islander
# item #487: name = BRADLEY STEVEN GRAHAM ; race = White
# item #488: name = ALTON EUGENE RALSTON ; race = Black
# item #489: name = BENJAMIN LEWIS RALSTON ; race = Black
# item #490: name = WILLIAM MARTIN CLARK ; race = White
# item #491: name = NATHAN JOHN CORT ; race = White
# item #492: name = AARON EUGENE FIELDS ; race = White
# item #493: name = DEON JAMEL MATHIS ; race = Black
# item #494: name = JENNIFER LORENE BABCOCK ; race = White
# item #495: name = LEXA LEANN MCCLARNON ; race = White
# item #496: name = ANNMARIE ROSALIE FRANCOIS ; race = White
# item #497: name = ANDRES DANIEL FLORES ; race = White
# item #498: name = BRIAN ANDRE RICHARD HOUSTON ; race = Black
# item #499: name = SHANE ALLAN GENOCHIO ; race = White
# item #500: name = SHANE ALLEN DEWEES ; race = White
# item #501: name = JAMES WALTER CROSKEY ; race = White
# item #502: name = RANDALL SCOTT STRONG ; race = White
# item #503: name = ANTONIO DAMON SHADE ; race = Black
# item #504: name = WILLIE LEE THOMPSON ; race = Black
# item #505: name = NICOLE JANELL LIND ; race = White
# item #506: name = ASHLEY MICHELLE AUGUSTINE ; race = White
# item #507: name = LARRY JOSEPH MILLER ; race = White
# item #508: name = FRANCISCO  SOTO ; race = White
# item #509: name = PHILIP WALTER GUSTAFSON ; race = White
# item #510: name = CHRISTOPHER BOBBY CLOUD ; race = Black
# item #511: name = MAXINE ETHEL SALAS ; race = White
# item #512: name = OSCAR ROLANDO GOMEZ BUSTAMANTE ; race = White
# item #513: name = JOSEPH GRANT EMERSON ; race = White
# item #514: name = LINDSEY ANN VISSER ; race = White
# item #515: name = PAUL ZACHARY PALMER ; race = White
# item #516: name = RAMONA LYNN GLICK ; race = White
# item #517: name = HEATHER MARIE ELSCHLAGER ; race = White
# item #518: name = ROBERT WILLIAM KUHN ; race = White
# item #519: name = ALEISA MARIE ARNETT ; race = White
# item #520: name = COLETTE RAE CONSTANTINOVICI ; race = White
# item #521: name = LOK TUT BOTH ; race = Black
# item #522: name = WILLIAM MARTIN ROGERS ; race = White
# item #523: name = BOUNTHONG JAMES PONGPHIMKHAM ; race = Asian
# item #524: name = SHAWN ALLEN HUGHLETTE ; race = White
# item #525: name = RUSSELL ALLEN MCKEEHAN ; race = White
# item #526: name = LOREN ALLEN LEWIS ; race = White
# item #527: name = MICHAEL JOHN ADZIMA ; race = White
# item #528: name = JERRY SHANE PRATT ; race = White
# item #529: name = TERRANCE ARTHUR REASBY ; race = Black
# item #530: name = IBRAHIM  BASS ; race = Black
# item #531: name = TANNER JAMES DALY ; race = White
# item #532: name = ALLEN LEWIS BERANEK ; race = White
# item #533: name = RAUDEL  PEREZ ; race = White
# item #534: name = MEDORA ANN PEDERSON ; race = White
# item #535: name = MICHAEL ALLEN NEWMAN ; race = White
# item #536: name = CARL DEWAYNE CUNNINGHAM ; race = White
# item #537: name = KAYDIN ENRICO MILANI OLER ; race = White
# item #538: name = TOMMY LEE BARTON ; race = White
# item #539: name = ALEX LARUE RITCHIE ; race = Black
# item #540: name = KRISTAL LOUISE RIDLEY ; race = Black
# item #541: name = JHON CHRISTOPHER MERRICK ; race = White
# item #542: name = JOSEPH LAWRENCE TATE ; race = Black
# item #543: name = CHARLES ERNEST MAYNARD ; race = White
# item #544: name = SHAWN LEE MILLER ; race = White
# item #545: name = KATHRYN ELIZABETH MORRISON ; race = White
# item #546: name = JOSEPH JUSTIN JOHNSON ; race = White
# item #547: name = COREY JAMISON LEONARD ; race = White
# item #548: name = FREDARIES CALVIN PATRICK ; race = Black
# item #549: name = MONTY DESHAWN HARPER ; race = Black
# item #550: name = MICHEAL RECO LYKE ; race = Black
# item #551: name = CHARLES EDWARD BITTNER ; race = White
# item #552: name = ASHLIE LYNNE GREEN ; race = White
# item #553: name = MICHAEL JAMES SPROUSE ; race = White
# item #554: name = TYLER DOUGLAS PRATT ; race = White
# item #555: name = MICHAEL ERNEST WINGFIELD ; race = White
# item #556: name = LILLIAN ROSELEE ECHOLS ; race = Black
# item #557: name = CLIFFORD EDWARD CHEERS ; race = Black
# item #558: name = ALLEN RAY SHEPHERD ; race = White
# item #559: name = BRANDI NICHOLE SIMMER ; race = White
# item #560: name = KEEGAN ALEXANDER LORENZ ; race = White
# item #561: name = ALBERTO RAYTON PACHECO ; race = White
# item #562: name = RAYMOND LYLE MCFADDEN ; race = White
# item #563: name = JOSEPH ROBERT JOSHUA ; race = Black
# item #564: name = DAVARIE RAY WATLEY ; race = Black
# item #565: name = PERNELL F GIVENS ; race = Black
# item #566: name = JARED DANIEL RESH ; race = White
# item #567: name = RICHARD MICHAEL EMERY ; race = White
# item #568: name = QUINTIN LATRELL EVANS ; race = Black
# item #569: name = CHANTELLE LEE WOLF ; race = White
# item #570: name = ALICIA MARIE FREESE ; race = White
# item #571: name = STEVEN DEAN BRADFORD ; race = White
# item #572: name = CURTIS EUGENE JAMES ; race = Black
# item #573: name = REGGIE LEE LOPEZ ; race = White
# item #574: name = LESLIE DAWN RICE ; race = White
# item #575: name = RYAN JUDE CARRINGTON ; race = White
# item #576: name = COLBY TYLER PONXS GREEN ; race = White
# item #577: name = HUNTER EUGENE BECKMAN ; race = White
# item #578: name = KATIE JEAN MILLER ; race = White
# item #579: name = TYLER DEREK FORMARO ; race = White
# item #580: name = BRITTANY RAE WALTERS ; race = White
# item #581: name = PATRICIO MACARIO GOMEZ ; race = White
# item #582: name = DUSTIN JAMES WITT ; race = White
# item #583: name = HOLLY MARIE MAHER ; race = White
# item #584: name = MEGAN MARIE BROOKS ; race = White
# item #585: name = JEDADHAIE DANIEL GRIFFIN ; race = Black
# item #586: name = RONALD MICHAEL WIESER ; race = White
# item #587: name = DARRELL DEAN SHOLLEY ; race = White
# item #588: name = DANIEL JUDE SUNG MCMAHON ; race = Asian
# item #589: name = JESSICA LUCILLE MASTERS ; race = White
# item #590: name = CHRISTOPHER JASON HANEY ; race = Black
# item #591: name = AUSTIN ROBERT RISELEY DUCHIN ; race = White
# item #592: name = JEFFREY KENT EATON ; race = White
# item #593: name = JOSEPH ANDREW STAFFORD ; race = White
# item #594: name = MELVIN DOUGLAS HAYGOOD ; race = Black
# item #595: name = MICHAEL FRANK BROUILLET ; race = White
# item #596: name = KYLE MARK GEORGE BAUER ; race = White
# item #597: name = BENJAMIN LEE HUSTED ; race = White
# item #598: name = JASON ALLAN BROWNING ; race = White
# item #599: name = KEVIN MARSHALL EASON ; race = White
# item #600: name = BRADLEY JARED TIMM ; race = White
# item #601: name = JAMES DAVID HAINES ; race = White
# item #602: name = REGINALD AKEEM JACKSON ; race = Black
# item #603: name = MONICA SUE MURRAY ; race = Black
# item #604: name = KIMBERLY RENEE SHAFER ; race = White
# item #605: name = KYLE LEE WADDELL ; race = White
# item #606: name = DANNY KAY SMITH ; race = Black
# item #607: name = SETH DANIEL TIMMER ; race = White
# item #608: name = JOSEPH CHARLES SIMPSON ; race = Black
# item #609: name = CARLOS  SALDANA ; race = White
# item #610: name = JONATHON DOLAND ANDERSON ; race = White
# item #611: name = NICOLE ELIZABETH BAGBY ; race = White
# item #612: name = AMBER DAWN JOHNSON ; race = White
# item #613: name = BRANDON PAUL HARRISON ; race = White
# item #614: name = BRIAN RAY WELTZIN ; race = White
# item #615: name = ALBERT  WHITESIDE ; race = Black
# item #616: name = ROBERT KYLE GATLIN ; race = White
# item #617: name = ANTHONY HERBERT SMITH ; race = White
# item #618: name = CLAUDE ROBERT CHIEF EAGLE ; race = Pacific Islander
# item #619: name = SONYA RAE GORDON ; race = White
# item #620: name = MYRON DESHAWN NEWTON ; race = Black
# item #621: name = TEOFILO  AGAPITO APOLINAR ; race = White
# item #622: name = NATALE NORMAN ISOLINI ; race = White
# item #623: name = DEVEN KILEY ANDERSON ; race = White
# item #624: name = LASANA VAYMULLION TOURE ; race = Black
# item #625: name = JIMMY DALE LEAF ; race = White
# item #626: name = NICOLE LYNN PARKER ; race = White
# item #627: name = JOHN RAY VILLALOBOS ; race = White
# item #628: name = KOLTON MICHAEL LINDMAN ; race = White
# item #629: name = FRANK MATHEW COOPER ; race = White
# item #630: name = LAVERN DEAN MACK ; race = White
# item #631: name = CHRISTOPHER LEE SMITH ; race = White
# item #632: name = MELONIE RENEE MAHFOUZ ; race = White
# item #633: name = KORY KEITH HARRIS ; race = White
# item #634: name = DARWIN LEROY BROWN ; race = White
# item #635: name = KEITH BRIAN BOYLAN ; race = White
# item #636: name = MARVIN OSWALDO ESQUIVEL LOPEZ ; race = White
# item #637: name = LILY MAY MARCELIS ; race = White
# item #638: name = JULIANO  LOPEZ DEJESUS ; race = Black
# item #639: name = SEAN MICHAEL OBOYLE ; race = White
# item #640: name = NICHOLAS DEWAYNE JERROLD STONE ; race = White
# item #641: name = MANUEL DEJESUS MATEO ENAMORADO ; race = White
# item #642: name = BENJAMIN MICHAEL WILLIAMS ; race = White
# item #643: name = MATTHEW DENNIS CARLSON ; race = White
# item #644: name = ROGELIO  MARTINEZ HERNANDEZ ; race = White
# item #645: name = BRANDON JAY DAVIS ; race = White
# item #646: name = JULIANNE JO BECKETT ; race = White
# item #647: name = WENDY SUE UTTER HERRICK ; race = White
# item #648: name = TIMOTHY ALLEN FENTON ; race = White
# item #649: name = BRIAN NAPOLES VARRON ; race = Asian
# item #650: name = ALFRED EUGENE CLEMENTS ; race = Black
# item #651: name = ERIC JAMES COLLINS ; race = Black
# item #652: name = DESEAN MARQUIS SIMS ; race = Black
# item #653: name = ABRAHAM PETRO RIKO ; race = Black
# item #654: name = SHANE LOUIS PETERSON ; race = Asian
# item #655: name = TAE SEON GLENN ; race = Asian
# item #656: name = RACHEL MARIE HAMMER ; race = White
# item #657: name = ANTHONY RUDOLPH AGOSTI ; race = White
# item #658: name = NATHANIEL MARTELL ACRI JOHNSON ; race = Black
# item #659: name = AVEN DAYNE GRANDSTAFF ; race = White
# item #660: name = DAJHA ESHAI WRIGHT ; race = Black
# item #661: name = RANDY JAMES MCCLAIN ; race = White
# item #662: name = MADELINE JANE DEAN ; race = White
# item #663: name = MICHAEL DAVID GOVEIA FIALHO ; race = White
# item #664: name = MATTHEW ANTHONY LEAVY ; race = White
# item #665: name = LAZEKE  SOUTHWARD ; race = Black
# item #666: name = KELLY EUGENE BURKS ; race = Black
# item #667: name = RYAN MICHAEL BURRIGHT ; race = White
# item #668: name = PATTI SUE SWANSON ; race = White
# item #669: name = RYAN ALLEN LARSEN ; race = White
# item #670: name = MICHAEL WAYNE LOVETT ; race = White
# item #671: name = DUSTIN ROBERT WING ; race = White
# item #672: name = ROBERT LEE MILLSAP ; race = Black
# item #673: name = IAN THOMAS HAMILL ; race = White
# item #674: name = DARREN JACOB HEIMANN ; race = White
# item #675: name = EMERSON LEE STRAYHORN ; race = White
# item #676: name = ZACHARY JOSEPH SMITH ; race = White
# item #677: name = RODNEY KEITH RASHAD RUSSELL ; race = Black
# item #678: name = JOSHUA DEAN RICHARDS ; race = White
# item #679: name = HUSSEIN NKUSU TAMBWE ; race = Black
# item #680: name = ERIC MATTHEW YOUNG ; race = Black
# item #681: name = STEVEN WAYNE SIX ; race = White
# item #682: name = RACAIL ALECE BRANDT ; race = White
# item #683: name = GRISELDA  SANCHEZ URQUIZA ; race = White
# item #684: name = FREDRICK ANTHONY RONALD KNAPP ; race = White
# item #685: name = AMBER SUE WARES ; race = White
# item #686: name = ZACHARY SCOTT MACY ; race = White
# item #687: name = JEFFREY LAMAR VIVIAN ; race = Black
# item #688: name = GARY CHARLES WOOD ; race = White
# item #689: name = JAMIE ALLEN BEESON ; race = White
# item #690: name = KENNETH ALLEN GANOE ; race = White
# item #691: name = MORICE DREW JONES ; race = Black
# item #692: name = VALOR JAMES KNAPP ; race = White
# item #693: name = DEMAJEE RAYSHON RIFE ; race = Black
# item #694: name = DANIEL JAY KADING ; race = Black
# item #695: name = ANTOWYNE WILLIAM DUPREE OSBORNE ; race = Black
# item #696: name = DANIEL PAUL BRANCO ; race = White
# item #697: name = MARCOS TEODORO VELARES GUAJIOLA ; race = White
# item #698: name = DEMI JOYCE LAWS ; race = White
# item #699: name = JUSTIN ALLAN DENNIS ; race = White
# item #700: name = CURTIS ANDREAS HILL QUIJANO ; race = White
# item #701: name = TYLER JEREMY OWENS ; race = White
# item #702: name = HAKEEM EMMANUEL ELLISON ; race = Black
# item #703: name = CHAD WESLEY WELBORN ; race = White
# item #704: name = JORDAN FARSHID ALLEN ; race = White
# item #705: name = ALIXZANDER CEZAR JAMES KOOKER ; race = White
# item #706: name = ALAN JAY REISMAN ; race = White
# item #707: name = VERNON JEWELL WALKER ; race = Black
# item #708: name = MARCUS QUSHAN BROWN ; race = Black
# item #709: name = JOSEPH ANTHONY CLAUSI ; race = White
# item #710: name = JACOB RICHARD MICHAEL OLEARY ; race = White
# item #711: name = STEVEN ALLEN BOYLAN ; race = White
# item #712: name = KEYA DION JEFFERSON ; race = Black
# item #713: name = PATRICK MICHAEL DAY ; race = White
# item #714: name = NICHOLAS RAY PIERSOL ; race = White
# item #715: name = BLAINE PATRICK FENNELLY ; race = White
# item #716: name = BREON DESEAN TEAGUE ; race = Black
# item #717: name = KEONA DELORES CAMPBELL ; race = Black
# item #718: name = RODNEY ALLEN SCHNOOR ; race = White
# item #719: name = RICHARD FORSTIER ADAIR ; race = White
# item #720: name = BOLOR  GANBAT ; race = Asian
# item #721: name = THOMAS EDWARD BROWN ; race = Black
# item #722: name = JUSTIN LEE JAMISON ; race = Black
# item #723: name = JOSHUA ADAM SCHIRO ; race = White
# item #724: name = ANGELA CHANTE JEFFERSON ; race = White
# item #725: name = RYAN LAMONTE PATTON STEWART ; race = Black
# item #726: name = HEIDI JO DYE ; race = White
# item #727: name = ANDREW CURTIS TAFTA ; race = White
# item #728: name = WILLIAM PAUL ANDREWS ; race = White
# item #729: name = DAN LEE TOOMEY ; race = White
# item #730: name = BRYAN DIMITRI LEZAY SIMPSON ; race = Black
# item #731: name = REBEKKA ROSE SANCHEZ WATKINS ; race = White
# item #732: name = CHRISTOPHER HERBERT LAWRENCE ; race = White
# item #733: name = JENSEN ELLIOTT SHOEMAKER ; race = White
# item #734: name = ERLALY TI-NGA ANDERSON ; race = White
# item #735: name = DAVID CHARLES THOMPSON ; race = White
# item #736: name = TEODORO  ALONSO ; race = White
# item #737: name = AKEEM YAUMAZE TROTTER ; race = Black
# item #738: name = ANDREW MICHAEL CHRISTENSEN ; race = Asian
# item #739: name = KEVIN DONYELL SMITH ; race = Black
# item #740: name = ROBERT BANKS ROLARK ; race = Black
# item #741: name = DEE  DU ; race = Asian
# item #742: name = GACHBAACH SIMON BILIM ; race = Black
# item #743: name = JASON RAY TINGLEY ; race = White
# item #744: name = JASON EDWARD KOOKER ; race = White
# item #745: name = JUSTIN ANTHONY VALENTI ; race = White
# item #746: name = DALLAS SAMUEL JAMES ALLEN ; race = White
# item #747: name = AARON ALEC WILLIAMS ; race = White
# item #748: name = RICARDO TYRONE SCOTT ; race = Black
# item #749: name = JAMES ANTHONY STEDDUM ; race = White
# item #750: name = JAMES NGANGA GACHII ; race = Black
# item #751: name = CUITLAHUAC  GUERRERO ; race = White
# item #752: name = CHAD DANIEL BEACH ; race = White
# item #753: name = RICHARD LEE DAVID BROWN ; race = Black
# item #754: name = NICKLAUS DUANE DELFRANO ; race = White
# item #755: name = TREVON YVES PHILLIPS ; race = Black
# item #756: name = DONNA SUE SINGH ; race = White
# item #757: name = JABIN MATTHEW HUNZIKER ; race = White
# item #758: name = MYRON ANTHONY ALLEN ; race = White
# item #759: name = MORGAN JAYNE BAKER ; race = White
# item #760: name = HILDA  AMBRIZ VALENCIA ; race = White
# item #761: name = TAB FRANCIS HARLAN ; race = Pacific Islander
# item #762: name = ANDREW WILLIAM LAPPE ; race = White
# item #763: name = VALERY  GARCIA ; race = White
# item #764: name = BRITTANY NICOLE NOELLE MUSICK ; race = White
# item #765: name = JOANNA ENDICOTT HULSEY ; race = White
# item #766: name = MICHAEL JEROME MARTIN ; race = Black
# item #767: name = FLOYD EUGENE STOCKDALL ; race = White
# item #768: name = MARVIN LEWIS NEWSOM ; race = White
# item #769: name = BANG TANG WUOL ; race = Black
# item #770: name = RICHARD ALLEN OBRYAN ; race = White
# item #771: name = KEITH FRANCIS FLOWER ; race = White
# item #772: name = NICOLE RENEE WALKER ; race = White
# item #773: name = TREVOR JOHN WOZNIAK ; race = White
# item #774: name = STEPHANIE ANN HARLOW ; race = White
# item #775: name = DUSTIN ELLIOTT WILLIAMS ; race = Black
# item #776: name = JACE PHILLIP CHALUP ; race = White
# item #777: name = KELLY EUGENE BURKS ; race = Black
# item #778: name = TYREE DE JOHN TAYLOR ; race = Black
# item #779: name = RYAN BLAKE WOODWARD ; race = White
# item #780: name = JOSHUA  BARJEBO ; race = Black
# item #781: name = YEN  YANN ; race = Asian
# item #782: name = JONATHAN ROY MURPHY ; race = White
# item #783: name = LARRY SAURRY GOLSTON ; race = Black
# item #784: name = MARSHALL LOUIS FIELD ; race = White
# item #785: name = MINDIE MARIE COX ; race = White
# item #786: name = ANDREW GRAY CAULKER ; race = Black
# item #787: name = BRIAN STEVEN HOCHGRABER ; race = White
# item #788: name = SHARON JO EASTER ; race = White
# item #789: name = DEANGELO DEVAUGHN ALLEN ; race = Black
# item #790: name = ROMEL MARTIN CABRERA ; race = White
# item #791: name = TORY CREYVON CASON ; race = Black
# item #792: name = ROBERT ISSAC SHIELDS ; race = White
# item #793: name = DEVIN JOSEPH BAILEY ; race = White
# item #794: name = JEREMY JAMES GREENING ; race = White
# item #795: name = KC  ABLETT ; race = White
# item #796: name = TRUMERE DAVONTE STEELE ; race = Black
# item #797: name = JOHN ALEXANDER TEMPLETON ; race = White
# item #798: name = BRIAN ADAM MARKS ; race = White
# item #799: name = DOMINICK GENE GRAMKOW ; race = Black
# item #800: name = JOSE ANIBAL RIVERA ; race = White
# item #801: name = MAKAVELI DEPREIST RUSSELL ; race = Black
# item #802: name = PHILLIP RANDOLPH LEWIS ; race = Black
# item #803: name = COREY MICHAEL MCDONALD ; race = White
# item #804: name = JONATHAN PAUL TONEY ; race = White
# item #805: name = JIBRIL ALI YUSSUF ; race = Black
# item #806: name = JESUS SAUL ZARAGOZA ZARAGOZA ; race = White
# item #807: name = ALEXIS JESUS PAREDES ; race = White
# item #808: name = KEVIN DEE BUTTS ; race = White
# item #809: name = MORGAN D`ETTE PETRIE LITTLE ; race = White
# item #810: name = MALACHI JAMES REED ; race = White
# item #811: name = LARONTEZ JAVON BUCHANAN ; race = Black
# item #812: name = ROBERT LEO WATSON ; race = White
# item #813: name = JAMES WINSTON JACKSON ; race = Black
# item #814: name = TERRY LEE WILFAWN ; race = White
# item #815: name = MARC ALAN PRESSWOOD ; race = Black
# item #816: name = ADAM DAVID CART ; race = White
# item #817: name = LYRIC DOMINIC TYLER HABECK ; race = White
# item #818: name = JESSE JAMES WILLIAM BAKER ; race = White
# item #819: name = ROOSEVELT ANTONIO INGRAM ; race = Black
# item #820: name = NATASHA LEANN MITCHELL ; race = White
# item #821: name = PATRICK WILLIAM TAYLOR ; race = Black
# item #822: name = AMANDA JEAN VANPELT ; race = White
# item #823: name = JEFFREY LEE DAWSON ; race = White
# item #824: name = MICHAEL CASSIN BURT ; race = White
# item #825: name = TALON DIAGO SCURLOCK ; race = Black
# item #826: name = WAYNE ANDRE FALKNER ; race = Black
# item #827: name = MICHAEL DEAN DEVORE ; race = White
# item #828: name = KENNETH DELL WHEELER ; race = White
# item #829: name = JOHNTAY RONNELL SINGLETON ; race = Black
# item #830: name = MARK ANTHONY SWATTA ; race = White
# item #831: name = DAWN DENISE MABRIER ; race = White
# item #832: name = JESSE DYLAN JOHNSON DACRE ; race = White
# item #833: name = FABRECE JAMAR BOWER TURNER ; race = Black
# item #834: name = ROBERT TROY JONES ; race = Black
# item #835: name = MARK ALAN DOYLE ; race = White
# item #836: name = DEANDRE RAYSHUN WOODEN ; race = Black
# item #837: name = ROBERT LEO HARRIS ; race = White
# item #838: name = VEDRAN  TADIC ; race = White
# item #839: name = ANTHONY KEVIN MORENO MURILLO ; race = White
# item #840: name = ALDEN JOSIA TURNER ; race = Black
# item #841: name = SHANIE  MOORE ; race = Black
# item #842: name = RICHARD LAVAN WAGNER ; race = Black
# item #843: name = THOMAS PATRICK OLOFSON ; race = White
# item #844: name = KELLIE RENEE KNAPP ; race = White
# item #845: name = TYLER DEAN OLESEN ; race = White
# item #846: name = BRIAN LEROY JEFFRIES ; race = White
# item #847: name = DEVANTE VASHAWN STEWART ; race = White
# item #848: name = JACK DELBERT FRANKLIN ; race = White
# item #849: name = TEKEZE LUGU KALIFA ; race = Black
# item #850: name = AMANIEL NUWAY ABRAHA ; race = Black
# item #851: name = TANI PAIGE KING ; race = White
# item #852: name = MARTIN EUGENE BEAULIEU ; race = White
# item #853: name = CEERON TEARRENCE WILLIAMS ; race = Black
# item #854: name = JOHN DAVID DAYE ; race = Black
# item #855: name = CANDICE MARIE ALBONDANTE ; race = White
# item #856: name = ELMER SALVADOR RIVERA GARCIA ; race = White
# item #857: name = KOURTNEY SHONTEZ HALL ; race = Black
# item #858: name = TYLOR ALLEN SHARP ; race = White
# item #859: name = RICKY LEE HAYGOOD ; race = Black
# item #860: name = RUOT GATWECH RUOT ; race = Black
# item #861: name = MARIO DUPRIE HUTCHINSON ; race = Black
# item #862: name = RYAN CAINE CONARD ; race = White
# item #863: name = IVORY LEE WASHINGTON ; race = Black
# item #864: name = FERID  HODZIC ; race = White
# item #865: name = DONTERIUS JAMAR BOMAR ; race = Black
# item #866: name = JOSHUA LEE ADAMS ; race = White
# item #867: name = EDWARD  MILLER ; race = Black
# item #868: name = SEAN MICHAEL FOSTER ; race = White
# item #869: name = MICHAEL WILLIAM TREAT ; race = White
# item #870: name = AKIL SALIM JABBAR ; race = Black
# item #871: name = DENNIS RAY BROWN ; race = White
# item #872: name = NICKOLOUS JEFFREY EARL ; race = Black
# item #873: name = CORNELIUS RICK DAVIS ; race = Black
# item #874: name = DAMIR JIRE YOUNG ; race = Black
# item #875: name = WILLIAM EDGAR BURTON ; race = White
# item #876: name = JAYDEN SIDNEY STRAIGHT ; race = White
# item #877: name = DUSTIN GLEN BLACK ; race = White
# item #878: name = MALIK TYRONE MANDUJANO ; race = Black
# item #879: name = TAYLOR LOUIS HARLAN ; race = White
# item #880: name = CORDERRO ALTON LAURENCE ; race = Black
# 881
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-6-facff3ff60f3> in <module>
#      13     print('item #{}:'.format(i),'name =', name, '; race =', race)
#      14 #
# ---> 15 assert print(len(inmate_names)) == total_inmates, "Some inmates' data is missing!"
#      16 assert print(len(inmate_races)) == total_inmates, "Some inmates' data is missing!"
#
# AssertionError: Some inmates' data is missing!

# %% [markdown]
# We can now close the Selenium WebDriver.

# %%
driver.close()

# %% [markdown]
# Now the table with the inmates' names and races is created. Notice that "Hispanic" or "Latino" is not shown in the list of unique values.

# %%
inmate_table = pd.DataFrame.from_dict({'Name':inmate_names, 'Race':inmate_races})
print("Race categories used in database: ", inmate_table['Race'].unique())
# Out:
# Race categories used in database:  ['White' 'Black' 'Unknown' 'Asian' 'Pacific Islander']

# %% [markdown]
# Inspecting the head of the table.

# %%
inmate_table.head()
# Out:
#                               Name     Race
# 0                   SHANE D MILLER    White
# 1              MARK ANTHONY WILSON    Black
# 2  SHAVAUGHN ELIZABETH KAY GARDNER    Black
# 3                  JULIE ANN LUNDY  Unknown
# 4              TYLOR MICHAEL DAVIS    White

# %% [markdown]
# ## Getting a list of common Hispanic names in the US

# %% [markdown]
# We are going to extract a list of common Hispanic names in the US. This is from the website Mongobay.com and the data is taken from the 2010 US Census. This list will be used to compare with the names of the inmates and guess whether or not they are hispanic.

# %%
url_common_lastnames = 'https://global.mongabay.com/es/nombres/hispanic.html'

response_common_lastnames = requests.get(url_common_lastnames)
soup_common_lastnames = BeautifulSoup(response_common_lastnames.text)
table = soup_common_lastnames.find_all(id='myTable')[0]

common_names_list = []
#There are 10 columns in this table, which is being processed as a list of strings using the .strings method.
#However, an extra column with '\n' is present at the beginning because of the HTML,
#so we are taking the name to be in the second column.
for i, s in enumerate(table.strings):
    if (i%11==1): common_names_list.append(s)
print(common_names_list[:3], '...', common_names_list[-3:]) #inspection of the result
# Out:
# ['Apellido', 'GARCIA', 'RODRIGUEZ'] ... ['CORIA', '\n', '\n']

# %% [markdown]
# We notice that the column title is at the beginning and there are two unwanted characters at the tail, so they are removed.

# %%
common_names_list.pop(0)
common_names_list.pop()
common_names_list.pop()
print('Total number of names:', len(common_names_list))
# Out:
# Total number of names: 979

# %% [markdown]
# Saving the list to a text file.

# %%
with open('common_list_names.txt', 'w') as f:
    for i in range(len(common_names_list)):
        f.write(common_names_list[i]+'\n')

# %%
#inmate_table['Race (compared)'] = 
inmate_table.apply(lambda x: True if len(set(inmate_table['Name'].str.split()).intersection(common_names))>0 else False)

# %%
common_names_set = set(common_names_list)

# %%
len(common_names_set)
# Out:
# 979

# %%
inmate_table.head()
# Out:
#                               Name     Race
# 0                   SHANE D MILLER    White
# 1              MARK ANTHONY WILSON    Black
# 2  SHAVAUGHN ELIZABETH KAY GARDNER    Black
# 3                  JULIE ANN LUNDY  Unknown
# 4              TYLOR MICHAEL DAVIS    White

# %%
def race_reviewed(df):
    if len(df['Name'].str.split().apply(set).intersection(common_names_set))>0:
        return "Hispanic"
    else:
        return df['Race']

# %%
inmate_table['Name'].str.split().apply(set).apply(set.intersection(common_names_set))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-c0d720aad33a> in <module>
# ----> 1 inmate_table['Name'].str.split().apply(set).apply(set.intersection(common_names_set))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4036             else:
#    4037                 values = self.astype(object).values
# -> 4038                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4039
#    4040         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# TypeError: 'set' object is not callable

# %%
inmate_table.apply(race_reviewed)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-647db3844209> in <module>
# ----> 1 inmate_table.apply(race_reviewed)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6904             kwds=kwds,
#    6905         )
# -> 6906         return op.get_result()
#    6907
#    6908     def applymap(self, func):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# <ipython-input-53-8aa035384a91> in race_reviewed(df)
#       1 def race_reviewed(df):
# ----> 2     if len(df['Name'].str.split().apply(set).intersection(common_names_set))>0:
#       3         return "Hispanic"
#       4     else:
#       5         return df['Race']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1062         key = com.apply_if_callable(key, self)
#    1063         try:
# -> 1064             result = self.index.get_value(self, key)
#    1065
#    1066             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4721         k = self._convert_scalar_indexer(k, kind="getitem")
#    4722         try:
# -> 4723             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4724         except KeyError as e1:
#    4725             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: ('Name', 'occurred at index Name')

# %%
inmate_table['Race (reviewed)'] = inmate_table['Name'].apply(lambda x: "Hispanic" if 
                                                             len(set(x.split()).intersection(common_names_set))>0
                                                             else
                          )
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 876    False
# 877    False
# 878     True
# 879     True
# 880    False
# Name: Name, Length: 881, dtype: bool

# %%
import numpy as np

# %%
np.loadtxt?

# %%
common_names = np.loadtxt('common_list_names.txt', dtype=str, unpack=True)

# %%
common_names[-1]

# %%
len(common_names)

# %%
test_name = 'MARIJKE JOY HODGSON'#'FELIXA  GOMEZ'

# %%
test_name.split()

# %%
np.where(common_names==test_name)
